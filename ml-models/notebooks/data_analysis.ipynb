# %% [markdown]
# # Scam Detection Data Analysis\nAnalyzing and preparing data for training

# %%
import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport seaborn as sns\nfrom wordcloud import WordCloud\nimport re

# %%
# Load your data\ndef load_data():\n    # Replace with your actual data\n    sample_data = [\n        ('Congratulations! You won R100,000!', 1),\n        ('Hi Mom, home at 6pm', 0)\n    ]\n    return pd.DataFrame(sample_data, columns=['text', 'label'])

# %%
df = load_data()\nprint(f'Dataset size: {len(df)}')\ndf.head()

# %%
# Class distribution\ndf['label_name'] = df['label'].map({1: 'Scam', 0: 'Legitimate'})\ndf['label_name'].value_counts().plot(kind='bar')\nplt.title('Class Distribution')\nplt.show()
